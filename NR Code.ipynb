# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel (r'CE Data from Apr 18 to Mar 19.xlsx', sheet_name='OPTIDX_NIFTY_CE_01-Apr-2018_TO_')

# %%
#xls.sheet_names

# %%
xls = pd.ExcelFile(r'C:\Users\hrish\Desktop\SoP Data\Final Sorted\Sorted CE data from April 18 to March 19.xlsx')

# %%
df = xls.parse(0)

# %%
df
# Out:
#    Symbol       Date     Expiry Option Type  Strike Price    Open    High  \
# 0   NIFTY 2018-04-02 2018-04-26          CE         10200  141.00  191.15
# 1   NIFTY 2018-04-03 2018-04-26          CE         10250  149.90  169.25
# 2   NIFTY 2018-04-04 2018-04-26          CE         10150  230.00  235.65
# 3   NIFTY 2018-04-05 2018-04-26          CE         10350   95.05  134.45
# 4   NIFTY 2018-04-06 2018-04-26          CE         10350  132.70  138.55
# 5   NIFTY 2018-04-09 2018-04-26          CE         10400   96.55  128.95
# 6   NIFTY 2018-04-10 2018-04-26          CE         10400  124.10  133.00
# 7   NIFTY 2018-04-11 2018-04-26          CE         10400  126.05  129.55
# 8   NIFTY 2018-04-12 2018-04-26          CE         10450   83.10  115.65
# 9   NIFTY 2018-04-13 2018-04-26          CE         10500   85.20  104.70
# 10  NIFTY 2018-04-16 2018-04-26          CE         10550   38.15   76.00
# 11  NIFTY 2018-04-17 2018-04-26          CE         10550   78.00   81.25
# ...

# %%
df.count()
# Out:
# Symbol                      1596
# Date                        1596
# Expiry                      1596
# Option Type                 1596
# Strike Price                1596
# Open                        1596
# High                        1596
# Low                         1596
# Close                       1596
# LTP                         1596
# Settle Price                1596
# No. of contracts            1596
# Turnover in Lacs            1596
# Premium Turnover in Lacs    1596
# Open Int                    1596
# Change in OI                1596
# Underlying Value            1596
# diff                        1596
# Dummy                       1596
# dtype: int64

# %%
Decimal(4)
# Out:
# Decimal('4')

# %%
Decimal((df['Expiry'][k] - df['Date'][k]).days*1.0)
# Out:
# Decimal('24')

# %%
def days_hours_minutes(td):
    return td.days, td.seconds//3600, (td.seconds//60)%60

# %% [markdown]
# # Approach 1

# %%
import scipy.stats as ss
from decimal import Decimal
import math as m
import numpy as np
from datetime import date,timedelta
#from mibian import BS

# K is option strike price; S0 is current price; r is risk free rate; T is time to maturity; Otype is call or put; Sig is imp_vol

def call_bsm (S0,K,r,T,Otype,sig):
    print("In Bsm")
    d1 = Decimal(m.log(S0/K)) + (r+ (sig*sig)/2)*T/(sig*Decimal(m.sqrt(T)))
    d2 = d1 - sig*Decimal(m.sqrt(T))
    if (Otype == "Call"):
        price = S0*Decimal(ss.norm.cdf(np.float(d1))) \
        - K*Decimal(m.exp(-r*T))*Decimal(ss.norm.cdf(np.float(d2)))
        return (price)
    elif (Otype == "Put"):
        price  = -S0*Decimal(ss.norm.cdf(np.float(-d1)))\
        + K*Decimal(m.exp(-r*T))*Decimal(ss.norm.cdf(np.float(-d2)))
        return (price)

def vega (S0,K,r,T,sig):
    #print("In Vega")
    d1 = Decimal(m.log(S0/K))/(sig*Decimal(m.sqrt(T))) + Decimal((r+ (sig*sig)/2)*T/(sig*Decimal(m.sqrt(T))))
    vega = S0*Decimal(ss.norm.pdf(np.float(d1)))*Decimal(m.sqrt(T))
    #print(vega)
    return(vega)
    
    
def imp_vol(S0, K, T, r, market,flag):
    e = 10e-3; x0 = Decimal(1);  
    def newtons_method(S0, K, T, r, market,flag,x0, e):
        #print("In NR")
        #print(market)
        mello = call_bsm (S0,K,r,T,flag,x0)
        #print(mello)
        delta = mello - market
        #print(delta)
        while delta > e:
            x0 = Decimal(x0 - ((call_bsm (S0,K,r,T,flag,x0) - market)/vega (S0,K,r,T,x0)))
            delta = abs(call_bsm (S0,K,r,T,flag,x0) - market)
            #print(delta," ",x0)
        return(Decimal(x0))
    sig =  newtons_method(S0, K, T, r, market,flag,x0 , e)   
    return(sig*100)

# %%
import pandas as pd
import xlrd
xls = pd.ExcelFile(r'C:\Users\hrish\Desktop\SoP Data\Final Sorted\Sorted CE data from April 18 to March 19.xlsx')

rf = pd.ExcelFile(r'C:\Users\hrish\Desktop\SoP Data\Treasury Bond Historical Data.xlsx')
s = rf.groupby('Date')

months = ['April','May','June','July','August','Sep','Oct','Nov','Dec,18','Jan,19','Feb,19','Mar,19']
n =0
for g in range(0,12):
    df = xls.parse(g)
    b = df[diff].count()
    n = n + b
for i in range(0,12):
    df = xls.parse(i)
    a = df.count()[0]
    c=[]
    h = df[diff].count()
    for k in range(0,a):
        print(Decimal(df['Underlying Value'][k]*1.0)," ",Decimal(df['Strike Price'][k]*1.0)," ",h/n)," ",Decimal(0.0625)," ",Decimal(df['Close'][k]),'Call')
        T = (h/n)  # time in expiry
        if(T!=0):
            iv = imp_vol(Decimal(df['Underlying Value'][k]*1.0),Decimal(df['Strike Price'][k]*1.0),h/n),Decimal(0.0625), Decimal(df['Close'][k]),'Call')
            print(iv)
            c.append(iv)
        else:
            c.append(0)
        h = h-1
    #c.append(0)
    df['Implied Volatility _ NR'] = c
    name = "sorted_with_imp_vol " + months[i] + ".xlsx"
    aname = "NR " + months[i]
    df.to_excel(name,sheet_name=aname, index=False)
# Out:
# 10211.79999999999927240423858165740966796875   10200   0.06666666666666666574148081281236954964697360992431640625   0.0625   185.099999999999994315658113919198513031005859375 Call
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# 14.92509623831193300392059272
# 10245   10250   0.0638888888888888839545643349993042647838592529296875   0.0625   163.099999999999994315658113919198513031005859375 Call
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# 14.01078039760638023617940570
# 10128.399999999999636202119290828704833984375   10150   0.061111111111111109106541761093467357568442821502685546875   0.0625   150.25 Call
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# 14.20681415206078432662126467
# 10325.149999999999636202119290828704833984375   10350   0.05833333333333333425851918718763045035302639007568359375   0.0625   130.650000000000005684341886080801486968994140625 Call
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# In Bsm
# ...

# %%
rf = pd.read_excel(r'C:\Users\hrish\Desktop\SoP Data\Treasury Bond Historical Data.xlsx')
s = rf.groupby('Date')
rf['Price']
# Out:
# 0      6.493
# 1      6.440
# 2      6.441
# 3      6.400
# 4      6.390
# 5      6.432
# 6      6.514
# 7      6.525
# 8      6.515
# 9      6.504
# 10     6.525
# 11     6.515
# 12     6.525
# 13     6.515
# 14     6.515
# 15     6.516
# 16     6.555
# 17     6.545
# 18     6.545
# 19     6.555
# 20     6.584
# 21     6.575
# 22     6.565
# 23     6.565
# 24     6.565
# 25     6.594
# 26     6.565
# 27     6.565
# 28     6.566
# 29     6.575
#        ...
# 233    6.700
# 234    6.654
# 235    6.620
# 236    6.594
# 237    6.670
# 238    6.550
# 239    6.543
# 240    6.520
# 241    6.549
# 242    6.477
# 243    6.461
# 244    6.453
# 245    6.459
# 246    6.488
# 247    6.543
# 248    6.563
# 249    6.526
# 250    6.625
# 251    6.609
# 252    6.631
# 253    6.649
# 254    6.590
# 255    6.600
# 256    6.584
# 257    6.623
# 258    6.685
# 259    6.677
# 260    6.670
# 261    6.671
# 262    6.658
# Name: Price, Length: 263, dtype: float64

# %%
fromdate = date(2018,3,30)
todate = date(2018,9,21)
daygenerator = (fromdate + timedelta(x + 1) for x in range((todate - fromdate).days))
days = sum(1 for day in daygenerator if day.weekday())
T = Decimal(days)/Decimal(360)    
S0 = Decimal(109.97)
K = Decimal(100)
market = Decimal(13.725)
flag = 'Call'
r = Decimal(0.0225)
iv = imp_vol(S0, K, T, r, market,flag)
print("")
print("")
print("############################ Newton Raphson Method ####################")
print("")
print('The implied volatility from my calculation is',iv,"%")
cp_iv = call_bsm(S0,K,r,T,Otype="Call",sig=Decimal(iv/100))
print('Newton Raphson implied volatility gives call price',cp_iv)
print("Error in obtained call price", '{:.20f}'.format(np.float(market - cp_iv)))
# Out:
# ############################ Newton Raphson Method ####################
#
# The implied volatility from my calculation is 28.74769495591848288387221528 %
# Newton Raphson implied volatility gives call price 13.72499999999999673631397958
# Error in obtained call price 0.00000000000000290841

# %% [markdown]
# # DATA

# %%
import pandas as pd
import xlrd
xls = pd.ExcelFile('CE Data from Apr 18 to Feb 19 (1).xlsx')
months = ['April','May','June','July','August','Sep','Oct','Nov','Dec,18','Jan,19','Feb,19','Mar,19']
for i in range(1,13):
    df = xls.parse(i)
    df['diff'] = abs(df['Strike Price']-df['Underlying Value'])
    s = df.groupby('Date')
    a=s.min()['diff'].count()
    t = df['diff'].count()
    c=[]
    prev = 0
    for x in range(0,a):
        for y in range(prev,prev + s.count()['Dummy'][x]):
            prev = prev+1
            if df['diff'][y] == s.min()['diff'][x] and df['Dummy'][y] == s.min()['Dummy'][x]:
                c.append(1)
            else:
                c.append(0)
            if y>=t:
                break
    df['check'] = c
    d2= df[df['check']>0]
    name = "D:\CHROME DOWNLOADS\SORTED" + "\sorted " + months[i-1] + ".xlsx"
    aname = "ATM_" + months[i-1]
    d2.to_excel(name,sheet_name=aname, index=False)

# %%
s = df.groupby('Date')

# %%
months = ['first']

# %%
name = "D:\CHROME DOWNLOADS\SORTED" + "\sorted" + months[0] + ".xlsx"

# %%
d2.to_excel(name,sheet_name='ATM-April', index=False)

# %%
a=s.min()['diff'].count()

# %%
df['diff'].count()
# Out:
# 1596

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
df['Date'][67].timestamp()
# Out:
# 1522627200.0

# %%
s.min()['Dummy'][0]
# Out:
# 192

# %%
t = df['diff'].count()

# %%
c=[]
for x in range(0,a):
    for y in range(x*84,x*84 + 84):
        if df['diff'][y] == s.min()['diff'][x] and df['Dummy'][y] == s.min()['Dummy'][x]:
            c.append(1)
        else:
            c.append(0)

# %%
df['check'] = c

# %%
s.min()['diff'][0]
# Out:
# 11.799999999999272

# %%
s.describe()
# Out:
#            Change in OI                                                    \
#                   count          mean            std        min       25%
# Date
# 2018-04-02         84.0   9669.642857  101134.172561  -345900.0      0.00
# 2018-04-03         84.0   9661.607143   85694.127398  -125025.0      0.00
# 2018-04-04         84.0  50478.571429  170894.885220  -219300.0      0.00
# 2018-04-05         84.0 -12003.571429  139852.682772  -745050.0  -1500.00
# 2018-04-06         84.0  -2918.750000   42753.297603  -189150.0   -937.50
# 2018-04-09         84.0   5483.928571   72592.538641  -235125.0   -318.75
# 2018-04-10         84.0   -395.535714   47393.450275  -289425.0  -1031.25
# 2018-04-11         84.0   1225.892857  160295.974151 -1123650.0  -1387.50
# 2018-04-12         84.0 -11714.285714   90358.272943  -594150.0  -2081.25
# 2018-04-13         84.0   1730.357143  210227.516851  -835200.0  -3468.75
# 2018-04-16         84.0  -7828.571429   62698.661755  -277725.0  -1593.75
# ...

# %%
s.count()['Dummy'][0]
# Out:
# 84

# %%
d2 = []
d2= df[df['check']>0]

# %%
d2
# Out:
#      Symbol       Date     Expiry Option Type  Strike Price    Open    High  \
# 54    NIFTY 2018-04-02 2018-04-26          CE         10200  141.00  191.15
# 139   NIFTY 2018-04-03 2018-04-26          CE         10250  149.90  169.25
# 221   NIFTY 2018-04-04 2018-04-26          CE         10150  230.00  235.65
# 309   NIFTY 2018-04-05 2018-04-26          CE         10350   95.05  134.45
# 373   NIFTY 2018-04-06 2018-04-26          CE         10350  132.70  138.55
# 478   NIFTY 2018-04-09 2018-04-26          CE         10400   96.55  128.95
# 562   NIFTY 2018-04-10 2018-04-26          CE         10400  124.10  133.00
# 646   NIFTY 2018-04-11 2018-04-26          CE         10400  126.05  129.55
# 731   NIFTY 2018-04-12 2018-04-26          CE         10450   83.10  115.65
# 816   NIFTY 2018-04-13 2018-04-26          CE         10500   85.20  104.70
# 901   NIFTY 2018-04-16 2018-04-26          CE         10550   38.15   76.00
# ...

# %%
d2.to_csv(r'D:\CHROME DOWNLOADS\SORTED\Sorted_April,18')

# %% [markdown]
# # NEWTON RAMPSON - A2

# %%
# -*- coding: utf-8 -*-
from scipy.stats import norm
import math

norm.cdf(1.96)
#c_p - Call(+1) or Put(-1) option
#P - Price of option
#S - Stock price
#E - Exercise price
#T - Time to expiration
#r - Risk-free rate

#C = SN(d_1) - Ee^{-rT}N(D_2)


def implied_volatility(Price,Stock,Exercise,Time,Rf):
    P = float(Price)
    S = float(Stock)
    E = float(Exercise)
    T = float(Time)
    r = float(Rf)
    sigma = 0.01 #initial estimate
    print (P, S, E, T, r)
    while sigma < 1:
        print("Hello")
        d_1 = float(float((math.log(S/E)+(r+(sigma**2)/2)*T))/float((sigma*(math.sqrt(T)))))
        d_2 = float(float((math.log(S/E)+(r-(sigma**2)/2)*T))/float((sigma*(math.sqrt(T)))))
        P_implied = float(S*norm.cdf(d_1) - E*math.exp(-r*T)*norm.cdf(d_2))
        if P-(P_implied) < 0.001:
            return sigma
        sigma +=0.001
    return "could not find the right volatility"
implied_volatility(185.1,10211.8,10200,1/12,0.06)
print (implied_volatility)
# Out:
# 185.1 10211.8 10200.0 0.08333333333333333 0.06
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
i = implied_volatility(185.1,10211.8,10200,1/12,0.06)
# Out:
# 185.1 10211.8 10200.0 0.08333333333333333 0.06
